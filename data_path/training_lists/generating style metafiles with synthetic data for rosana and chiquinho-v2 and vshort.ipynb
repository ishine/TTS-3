# %% [markdown]
# # Testing bias

# %%
import pandas as pd
import librosa
import IPython.display as ipd

df = pd.read_csv('mp_styles_train.csv', sep=';')

# %%
df.head(3)
# Out:
#                               phonetic_transcription  \
# 0  #p kk uu uw ts ii vv 'aa rr un bb uu zz 'ee ij...
# 1  #p bb uu rr 'aa kk uc nn ac 'aa rf vv oo rr ic...
# 2  #p aa kk rd ee dz 'ii tt uc kk ic ss 'ee zh ac...
#
#                                             wav_path  speaker      style
# 0  /l/disk1/awstebas/data/TTS/speaker-adriana/eps...  adriana    animado
# 1  /l/disk1/awstebas/data/TTS/speaker-adriana/eps...  adriana  acolhedor
# 2  /l/disk1/awstebas/data/TTS/speaker-adriana/eps...  adriana    animado

# %%
print(df['phonetic_transcription'].values[0])
ipd.Audio(df['wav_path'].values[0])
# Out:
# #p kk uu uw ts ii vv 'aa rr un bb uu zz 'ee ij rr uc zz nn uc ll 'eh ss ts ic 'eh ac 'uu nn ic kk ac kk 'oo ij zz ac vv 'aa ll ic dd ac #p
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !ls /l/disk1/awstebas/lhueda/github/se-so-vits-svc/assets

# %%
# !cp /l/disk1/awstebas/lhueda/github/se-so-vits-svc/assets/mp_synt_styles_train2.csv ./mp_synt_styles_train2.csv

# %%
df_synth = pd.read_csv('mp_synt_styles_train2.csv', sep=',') # It was wrong
df_synth.speaker.value_counts()
# Out:
# rosana       3672
# chiquinho    3672
# Name: speaker, dtype: int64

# %%
df_synth.head()
# Out:
#                               phonetic_transcription  \
# 0  #p kk uu uw ts ii vv 'aa rr un bb uu zz 'ee ij...
# 1  #p bb uu rr 'aa kk uc nn ac 'aa rf vv oo rr ic...
# 2  #p aa kk rd ee dz 'ii tt uc kk ic ss 'ee zh ac...
# 3  #p rx ee nn 'oh vv ic ss 'uu ac kk 'aa zz ac k...
# 4  #p ff 'aa ij sh ac zz dd ac kk aa tt ee gg oo ...
#
#                                             wav_path speaker      style
# 0  /l/disk1/awstebas/lhueda/github/data/rosana_ca...  rosana    animado
# 1  /l/disk1/awstebas/lhueda/github/data/rosana_ca...  rosana  acolhedor
# 2  /l/disk1/awstebas/lhueda/github/data/rosana_ca...  rosana    animado
# 3  /l/disk1/awstebas/lhueda/github/data/rosana_ca...  rosana  acolhedor
# 4  /l/disk1/awstebas/lhueda/github/data/rosana_ca...  rosana  acolhedor

# %%
print(df_synth['phonetic_transcription'].values[0])
ipd.Audio(df_synth['wav_path'].values[0])
# Out:
# #p kk uu uw ts ii vv 'aa rr un bb uu zz 'ee ij rr uc zz nn uc ll 'eh ss ts ic 'eh ac 'uu nn ic kk ac kk 'oo ij zz ac vv 'aa ll ic dd ac #p
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
df.speaker.value_counts()
# Out:
# adriana      7073
# rosana       6684
# chiquinho    4680
# Name: speaker, dtype: int64

# %%
df_full = pd.concat([df, df_synth]).reset_index(drop=True)
df_full.speaker.value_counts()
# Out:
# rosana       10356
# chiquinho     8352
# adriana       7073
# Name: speaker, dtype: int64

# %%
df_full.shape
# Out:
# (25781, 4)

# %%
df_full.head()
# Out:
#                               phonetic_transcription  \
# 0  #p kk uu uw ts ii vv 'aa rr un bb uu zz 'ee ij...
# 1  #p bb uu rr 'aa kk uc nn ac 'aa rf vv oo rr ic...
# 2  #p aa kk rd ee dz 'ii tt uc kk ic ss 'ee zh ac...
# 3  #p uc bb aa rr 'uu lh uc dd ac rx 'uu ac nn 'a...
# 4  #p aa kk 'ee ll ic ss kk ic dz 'ii zz en kk ic...
#
#                                             wav_path  speaker      style
# 0  /l/disk1/awstebas/data/TTS/speaker-adriana/eps...  adriana    animado
# 1  /l/disk1/awstebas/data/TTS/speaker-adriana/eps...  adriana  acolhedor
# 2  /l/disk1/awstebas/data/TTS/speaker-adriana/eps...  adriana    animado
# 3  /l/disk1/awstebas/data/TTS/speaker-adriana/eps...  adriana     neutro
# 4  /l/disk1/awstebas/data/TTS/speaker-adriana/eps...  adriana     neutro

# %%
df_full.tail()
# Out:
#                                   phonetic_transcription  \
# 25776  #p zh 'aa ss ic pp aa ss 'aa rr an wn mm 'aa i...
# 25777  #p kk ll 'aa rr uc kk ic nn 'an wn kk 'eh rr u...
# 25778  #p ic 'eh 'uu mm ac dd ac zz ll 'ee ij ss kk i...
# 25779  #p pp 'aa rr ac bb uu ss kk 'aa rf ss 'ee uw s...
# 25780  #p 'eh ll ac pp oo dd ee rr 'ii ac kk oo bb rd...
#
#                                                 wav_path    speaker      style
# 25776  /l/disk1/awstebas/lhueda/github/data/rosana_ca...  chiquinho    rispido
# 25777  /l/disk1/awstebas/lhueda/github/data/rosana_ca...  chiquinho    rispido
# 25778  /l/disk1/awstebas/lhueda/github/data/rosana_ca...  chiquinho  acolhedor
# 25779  /l/disk1/awstebas/lhueda/github/data/rosana_ca...  chiquinho  acolhedor
# 25780  /l/disk1/awstebas/lhueda/github/data/rosana_ca...  chiquinho    animado

# %%
cols = ['phonetic_transcription', 'wav_path', 'speaker','style']

df_full[cols].to_csv('mp_styles_train_synthetic_aug_v2.csv', index = False, sep=';', encoding = 'utf-8')
# df_val_tot[cols].to_csv('mp_styles_val.csv', index = False, sep=';', encoding = 'utf-8')

# %% [markdown]
# # Short version 30% of synthetic speech

# %%
df_synthstrat = pd.concat([df_synth[df_synth['speaker']=='chiquinho'].sample(frac=.3, random_state=42), df_synth[df_synth['speaker']=='rosana'].sample(frac=.3, random_state=13)]).reset_index(drop=True)
df_full = pd.concat([df, df_synthstrat]).reset_index(drop=True)
df_full.speaker.value_counts()
# Out:
# rosana       7786
# adriana      7073
# chiquinho    5782
# Name: speaker, dtype: int64

# %%
df_full.shape
# Out:
# (20641, 4)

# %%
df_full.tail()
# Out:
#                                   phonetic_transcription  \
# 20636  #p aa ss 'eh ss uc ac dd 'aa dd uc zz ic ss ee...
# 20637  #p ic ss 'aa bb ac dd uc dd ac zz 'oo ij tt uc...
# 20638  #p nn 'oh ss tt oo mm 'an mm uc zz un kk aa mm...
# 20639  #p kk 'eh rr uc mm 'un in tt uc ts ic kk on tt...
# 20640  #p ac 'aa gg uw ac dd ac pp ii ss 'ii nn ac ee...
#
#                                                 wav_path speaker      style
# 20636  /l/disk1/awstebas/lhueda/github/data/rosana_ca...  rosana    rispido
# 20637  /l/disk1/awstebas/lhueda/github/data/rosana_ca...  rosana    animado
# 20638  /l/disk1/awstebas/lhueda/github/data/rosana_ca...  rosana    rispido
# 20639  /l/disk1/awstebas/lhueda/github/data/rosana_ca...  rosana  acolhedor
# 20640  /l/disk1/awstebas/lhueda/github/data/rosana_ca...  rosana    animado

# %%
cols = ['phonetic_transcription', 'wav_path', 'speaker','style']

df_full[cols].to_csv('mp_styles_train_synthetic_aug_v2_30pct.csv', index = False, sep=';', encoding = 'utf-8')
# df_val_tot[cols].to_csv('mp_styles_val.csv', index = False, sep=';', encoding = 'utf-8')
