# %%
import pandas as pd
import librosa
import IPython.display as ipd

# %%
df = pd.read_csv('universal_cpqd_train.csv', sep=';')

# %%
df
# Out:
#                                   phonetic_transcription  \
# 0      #p vv oo ss 'ee kk 'eh rr aa zh en dd 'aa rf s...
# 1      #p vv oo ss 'ee kk 'eh rr aa zh en dd 'aa rr e...
# 2      #p pp 'aa rr ac kk uw 'an dd uc vv oo ss 'ee g...
# 3      #p vv oo ss 'ee pp 'oh dz ic rx ee aa zh en dd...
# 4      #p gg oo ss tt aa rr 'ii ac dz ic rx ee aa zh ...
# ...                                                  ...
# 39717           #p mm 'ee zz dz ic aa gg 'oo ss tt uc #q
# 39718        #p mm 'ee zz dz ic ss ee tt 'en bb rd uc #q
# 39719        #p mm 'ee zz dz ic oo uw tt 'uu bb rd uc #q
# 39720        #p mm 'ee zz dz ic nn oo vv 'en bb rd uc #q
# 39721        #p mm 'ee zz dz ic dd ee zz 'en bb rd uc #q
#
#                                                 wav_path  speaker
# 0      /l/disk1/awstebas/data/TTS/speaker-adriana/aec...  adriana
# 1      /l/disk1/awstebas/data/TTS/speaker-adriana/aec...  adriana
# 2      /l/disk1/awstebas/data/TTS/speaker-adriana/aec...  adriana
# ...

# %%
print(df['phonetic_transcription'].values[0])
ipd.Audio(df['wav_path'].values[0])
# Out:
# #p vv oo ss 'ee kk 'eh rr aa zh en dd 'aa rf ss 'ee uw zz ee zz 'an mm ic ss #q
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
n = 13
print(df['phonetic_transcription'].values[n])
ipd.Audio(df['wav_path'].values[n])
# Out:
# #p dz ii zh 'ii ts ic ss 'eh ts ic pp 'aa rr ac ss 'in ic nn 'oh vv ic pp 'aa rr ac nn 'an wn #p
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
n = -13
print(df['phonetic_transcription'].values[n])
ipd.Audio(df['wav_path'].values[n])
# Out:
# #p mm 'ee zz dz ic zh aa nn 'ee ij rr uc #q
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
n = -8000
print(df['phonetic_transcription'].values[n])
ipd.Audio(df['wav_path'].values[n])
# Out:
# #p pp 'aa rr ac ee ss tt uu dd 'aa rf zh ee oo gg rd aa ff 'ii ac ic ee ss tt aa ts 'ii ss ts ic kk ac kk on 'ee ll ic ss #p
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
